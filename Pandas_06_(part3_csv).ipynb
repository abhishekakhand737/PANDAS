# %% [markdown]
# ## CSV #Part3

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
df
# Out:
#        ID             Name            COMPANIES   Inception       Revenue  \
# 0       1          Lamtone          IT Services        2009   $11,757,018
# 1       2        Stripfind   Financial Services        2010   $12,329,371
# 2       3  Canecorporation               Health        2012   $10,597,009
# 3       4         Mattouch               Health        2013   $14,026,934
# 4       5        Techdrill               Health        2009  $13,898,119
# 5       6         Techline               Health        2006   $12,98,119
# 6       7          Cityace          IT Services        2010   $9,254,614
# 7       8   Kayelectronics        not available        2009   $9,451,943
# 8       9          Ganzlax          IT Services        2011  $14,001,180
# 9      10      Trantraxlax  Government Services        2011  $11,088,336
#
#             Expenses     Profit   Growth
# 0  7,435,363 Dollars    5274553      30%
# 1    916,455 Dollars   11412916      20%
# ...

# %% [markdown]
# #### First Method of PANDAS (Head)

# %%
# Prints first 5  top rows
df.head()
# Out:
#    1          Lamtone         IT Services  2009  $11,757,018   \
# 0  2        Stripfind  Financial Services  2010  $12,329,371
# 1  3  Canecorporation              Health  2012  $10,597,009
# 2  4         Mattouch         IT Services  2013  $14,026,934
# 3  5        Techdrill              Health  2009  $10,573,990
# 4  6         Techline              Health  2006  $13,898,119
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  26%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%

# %%
df.head(1)
# Out:
#    1    Lamtone         IT Services  2009  $11,757,018  6,482,465 Dollars  \
# 0  2  Stripfind  Financial Services  2010  $12,329,371    916,455 Dollars
#
#     5274553  30%
# 0  11412916  20%

# %%
df.head(7)
# Out:
#    1          Lamtone         IT Services  2009  $11,757,018   \
# 0  2        Stripfind  Financial Services  2010  $12,329,371
# 1  3  Canecorporation              Health  2012  $10,597,009
# 2  4         Mattouch         IT Services  2013  $14,026,934
# 3  5        Techdrill              Health  2009  $10,573,990
# 4  6         Techline              Health  2006  $13,898,119
# 5  7          Cityace              Health  2010   $9,254,614
# 6  8   Kayelectronics              Health  2009   $9,451,943
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  26%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%

# %% [markdown]
# #### Tail

# %%
# Prints first 5 bottom rows
df.tail()
# Out:
#     1         Lamtone          IT Services  2009  $11,757,018   \
# 4   6        Techline               Health  2006  $13,898,119
# 5   7         Cityace               Health  2010   $9,254,614
# 6   8  Kayelectronics               Health  2009   $9,451,943
# 7   9         Ganzlax          IT Services  2011  $14,001,180
# 8  10     Trantraxlax  Government Services  2011  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%
# 7                NaN  11901180  18%
# 8  5,635,276 Dollars   5453060   7%

# %%
df.tail(3)
# Out:
#     1         Lamtone          IT Services  2009  $11,757,018   \
# 6   8  Kayelectronics               Health  2009   $9,451,943
# 7   9         Ganzlax          IT Services  2011  $14,001,180
# 8  10     Trantraxlax  Government Services  2011  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 6  3,878,113 Dollars   5573830   4%
# 7                NaN  11901180  18%
# 8  5,635,276 Dollars   5453060   7%

# %%
df.tail(6)
# Out:
#     1         Lamtone          IT Services  2009  $11,757,018   \
# 3   5       Techdrill               Health  2009  $10,573,990
# 4   6        Techline               Health  2006  $13,898,119
# 5   7         Cityace               Health  2010   $9,254,614
# 6   8  Kayelectronics               Health  2009   $9,451,943
# 7   9         Ganzlax          IT Services  2011  $14,001,180
# 8  10     Trantraxlax  Government Services  2011  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%
# 7                NaN  11901180  18%
# 8  5,635,276 Dollars   5453060   7%

# %% [markdown]
# ### DATA Type (Changing Data Type)

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', dtype = {'1': 'float64'})
df
# Out:
#       1          Lamtone          IT Services  2009  $11,757,018   \
# 0   2.0        Stripfind   Financial Services  2010  $12,329,371
# 1   3.0  Canecorporation               Health  2012  $10,597,009
# 2   4.0         Mattouch          IT Services  2013  $14,026,934
# 3   5.0        Techdrill               Health  2009  $10,573,990
# 4   6.0         Techline               Health  2006  $13,898,119
# 5   7.0          Cityace               Health  2010   $9,254,614
# 6   8.0   Kayelectronics               Health  2009   $9,451,943
# 7   9.0          Ganzlax          IT Services  2011  $14,001,180
# 8  10.0      Trantraxlax  Government Services  2011  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  26%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%
# ...

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', dtype = {'1': 'float64','2009':'float64'})
df
# Out:
#       1          Lamtone          IT Services    2009  $11,757,018   \
# 0   2.0        Stripfind   Financial Services  2010.0  $12,329,371
# 1   3.0  Canecorporation               Health  2012.0  $10,597,009
# 2   4.0         Mattouch          IT Services  2013.0  $14,026,934
# 3   5.0        Techdrill               Health  2009.0  $10,573,990
# 4   6.0         Techline               Health  2006.0  $13,898,119
# 5   7.0          Cityace               Health  2010.0   $9,254,614
# 6   8.0   Kayelectronics               Health  2009.0   $9,451,943
# 7   9.0          Ganzlax          IT Services  2011.0  $14,001,180
# 8  10.0      Trantraxlax  Government Services  2011.0  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  26%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%
# ...

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
df
# Out:
#        ID Date             Name            COMPANIES   Inception  \
# 0       1  Yes          Lamtone          IT Services        2009
# 1       2  Yes        Stripfind   Financial Services        2010
# 2       3  Yes  Canecorporation               Health        2012
# 3       4  Yes         Mattouch               Health        2013
# 4       5  Yes        Techdrill               Health        2009
# 5       6  Yes         Techline               Health        2006
# 6       7  Yes          Cityace          IT Services        2010
# 7       8  Yes   Kayelectronics        not available        2009
# 8       9  Yes          Ganzlax          IT Services        2011
# 9      10  Yes      Trantraxlax  Government Services        2011
#
#         Revenue           Expenses     Profit   Growth
# 0   $11,757,018  7,435,363 Dollars    5274553      30%
# 1   $12,329,371    916,455 Dollars   11412916      20%
# 2   $10,597,009    916,455 Dollars    3005820       7%
# ...

# %% [markdown]
# ### True values

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', true_values = ['Yes'])
df
# Out:
#        ID  Date             Name            COMPANIES   Inception  \
# 0       1  True          Lamtone          IT Services        2009
# 1       2  True        Stripfind   Financial Services        2010
# 2       3  True  Canecorporation               Health        2012
# 3       4  True         Mattouch               Health        2013
# 4       5  True        Techdrill               Health        2009
# 5       6  True         Techline               Health        2006
# 6       7  True          Cityace          IT Services        2010
# 7       8  True   Kayelectronics        not available        2009
# 8       9  True          Ganzlax          IT Services        2011
# 9      10  True      Trantraxlax  Government Services        2011
#
#         Revenue           Expenses     Profit   Growth
# 0   $11,757,018  7,435,363 Dollars    5274553      30%
# 1   $12,329,371    916,455 Dollars   11412916      20%
# 2   $10,597,009    916,455 Dollars    3005820       7%
# ...

# %% [markdown]
# ### False values

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
df
# Out:
#        ID Date             Name            COMPANIES   Inception  \
# 0       1  Yes          Lamtone          IT Services        2009
# 1       2   No        Stripfind   Financial Services        2010
# 2       3   No  Canecorporation               Health        2012
# 3       4   No         Mattouch               Health        2013
# 4       5   No        Techdrill               Health        2009
# 5       6  Yes         Techline               Health        2006
# 6       7  Yes          Cityace          IT Services        2010
# 7       8  Yes   Kayelectronics        not available        2009
# 8       9  Yes          Ganzlax          IT Services        2011
# 9      10  Yes      Trantraxlax  Government Services        2011
#
#         Revenue           Expenses     Profit   Growth
# 0   $11,757,018  7,435,363 Dollars    5274553      30%
# 1   $12,329,371    916,455 Dollars   11412916      20%
# 2   $10,597,009    916,455 Dollars    3005820       7%
# ...

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', true_values = ['Yes'],false_values=['No'])
df
# Out:
#        ID   Date             Name            COMPANIES   Inception  \
# 0       1   True          Lamtone          IT Services        2009
# 1       2  False        Stripfind   Financial Services        2010
# 2       3  False  Canecorporation               Health        2012
# 3       4  False         Mattouch               Health        2013
# 4       5  False        Techdrill               Health        2009
# 5       6   True         Techline               Health        2006
# 6       7   True          Cityace          IT Services        2010
# 7       8   True   Kayelectronics        not available        2009
# 8       9   True          Ganzlax          IT Services        2011
# 9      10   True      Trantraxlax  Government Services        2011
#
#         Revenue           Expenses     Profit   Growth
# 0   $11,757,018  7,435,363 Dollars    5274553      30%
# 1   $12,329,371    916,455 Dollars   11412916      20%
# 2   $10,597,009    916,455 Dollars    3005820       7%
# ...

# %%
## head(),tail(),dtype,true_values & false_value
