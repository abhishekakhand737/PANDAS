# %% [markdown]
# ## Handling Missing Values in Python

# %%
import pandas as pd

# %%
 df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
 df
# Out:
#        ID             Name            COMPANIES   Inception       Revenue  \
# 0       1          Lamtone          IT Services        2009  $11,757,018
# 1       2        Stripfind   Financial Services        2010  $12,329,371
# 2       3  Canecorporation               Health        2012  $10,597,009
# 3       4         Mattouch          IT Services        2013  $14,026,934
# 4       5        Techdrill               Health        2009  $10,573,990
# 5       6         Techline               Health        2006  $13,898,119
# 6       7          Cityace               Health        2010   $9,254,614
# 7       8   Kayelectronics               Health        2009   $9,451,943
# 8       9          Ganzlax          IT Services        2011  $14,001,180
# 9      10      Trantraxlax  Government Services        2011  $11,088,336
#
#             Expenses     Profit   Growth
# 0  6,482,465 Dollars    5274553      30%
# 1    916,455 Dollars   11412916      20%
# ...

# %% [markdown]
# ### NaN (Not a Number)
# ###### It represents missing or undefined values in a dataset.

# %%
 df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
 df
# Out:
#        ID             Name            COMPANIES   Inception       Revenue  \
# 0       1          Lamtone          IT Services        2009  $11,757,018
# 1       2        Stripfind   Financial Services        2010  $12,329,371
# 2       3  Canecorporation               Health        2012  $10,597,009
# 3       4         Mattouch                  NaN        2013  $14,026,934
# 4       5        Techdrill                  NaN        2009  $10,573,990
# 5       6         Techline                  NaN        2006  $13,898,119
# 6       7          Cityace          IT Services        2010   $9,254,614
# 7       8   Kayelectronics                    I        2009   $9,451,943
# 8       9          Ganzlax          IT Services        2011  $14,001,180
# 9      10      Trantraxlax  Government Services        2011  $11,088,336
#
#             Expenses      Profit   Growth
# 0                NaN   5274553.0      30%
# 1    916,455 Dollars  11412916.0      20%
# ...

# %%
 #N/A Null values replaced by NaN
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
df
# Out:
#        ID             Name            COMPANIES   Inception       Revenue  \
# 0       1          Lamtone          IT Services        2009  $11,757,018
# 1       2        Stripfind   Financial Services        2010  $12,329,371
# 2       3  Canecorporation               Health        2012  $10,597,009
# 3       4         Mattouch                  NaN        2013  $14,026,934
# 4       5        Techdrill                  NaN        2009  $10,573,990
# 5       6         Techline                  NaN        2006  $13,898,119
# 6       7          Cityace          IT Services        2010   $9,254,614
# 7       8   Kayelectronics                    I        2009   $9,451,943
# 8       9          Ganzlax          IT Services        2011  $14,001,180
# 9      10      Trantraxlax  Government Services        2011  $11,088,336
#
#             Expenses      Profit   Growth
# 0                NaN   5274553.0      30%
# 1    916,455 Dollars  11412916.0      20%
# ...

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
df
# Out:
#        ID             Name            COMPANIES   Inception        Revenue  \
# 0       1          Lamtone          IT Services        2009   $11,757,018
# 1       2        Stripfind   Financial Services        2010   $12,329,371
# 2       3  Canecorporation               Health        2012  not available
# 3       4         Mattouch                  NaN        2013  not available
# 4       5        Techdrill                  NaN        2009   $10,573,990
# 5       6         Techline                  NaN        2006   $13,898,119
# 6       7          Cityace          IT Services        2010    $9,254,614
# 7       8   Kayelectronics        not available        2009    $9,451,943
# 8       9          Ganzlax          IT Services        2011   $14,001,180
# 9      10      Trantraxlax  Government Services        2011   $11,088,336
#
#             Expenses      Profit   Growth
# 0                NaN   5274553.0      30%
# 1    916,455 Dollars  11412916.0      20%
# ...

# %% [markdown]
# #### Not Available is replaced by NAN from above dataset

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', na_values = 'not available')
df
# Out:
#        ID             Name            COMPANIES   Inception       Revenue  \
# 0       1          Lamtone          IT Services        2009  $11,757,018
# 1       2        Stripfind   Financial Services        2010  $12,329,371
# 2       3  Canecorporation               Health        2012           NaN
# 3       4         Mattouch            no values        2013           NaN
# 4       5        Techdrill                  NaN        2009  $10,573,990
# 5       6         Techline                  NaN        2006  $13,898,119
# 6       7          Cityace          IT Services        2010   $9,254,614
# 7       8   Kayelectronics                  NaN        2009   $9,451,943
# 8       9          Ganzlax          IT Services        2011  $14,001,180
# 9      10      Trantraxlax  Government Services        2011  $11,088,336
#
#             Expenses      Profit   Growth
# 0                NaN   5274553.0      30%
# 1    916,455 Dollars  11412916.0      20%
# ...

# %% [markdown]
# #### No values is replaced by NAN from above dataset

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', na_values = ['not available', 'no values'])
df
# Out:
#        ID             Name            COMPANIES   Inception       Revenue  \
# 0       1          Lamtone          IT Services        2009  $11,757,018
# 1       2        Stripfind   Financial Services        2010  $12,329,371
# 2       3  Canecorporation               Health        2012           NaN
# 3       4         Mattouch                  NaN        2013           NaN
# 4       5        Techdrill                  NaN        2009  $10,573,990
# 5       6         Techline                  NaN        2006  $13,898,119
# 6       7          Cityace          IT Services        2010   $9,254,614
# 7       8   Kayelectronics                  NaN        2009   $9,451,943
# 8       9          Ganzlax          IT Services        2011  $14,001,180
# 9      10      Trantraxlax  Government Services        2011  $11,088,336
#
#             Expenses      Profit   Growth
# 0                NaN   5274553.0      30%
# 1    916,455 Dollars  11412916.0      20%
# ...

# %% [markdown]
# #### Specific coloumn NAN values

# %%
 df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
 df
# Out:
#        ID             Name            COMPANIES   Inception        Revenue  \
# 0       1          Lamtone          IT Services        2009   $11,757,018
# 1       2        Stripfind   Financial Services        2010   $12,329,371
# 2       3  Canecorporation               Health        2012  not available
# 3       4         Mattouch            no values        2013  not available
# 4       5        Techdrill                  NaN        2009   $10,573,990
# 5       6         Techline                  NaN        2006   $13,898,119
# 6       7          Cityace          IT Services        2010    $9,254,614
# 7       8   Kayelectronics        not available        2009    $9,451,943
# 8       9          Ganzlax          IT Services        2011   $14,001,180
# 9      10      Trantraxlax  Government Services        2011   $11,088,336
#
#             Expenses      Profit   Growth
# 0                NaN   5274553.0      30%
# 1    916,455 Dollars  11412916.0      20%
# ...

# %%
 df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', na_values = {'COMPANIES': 'no values', 'Profit': 'not available'})
 df
# Out:
#        ID             Name            COMPANIES   Inception        Revenue  \
# 0       1          Lamtone          IT Services        2009   $11,757,018
# 1       2        Stripfind   Financial Services        2010   $12,329,371
# 2       3  Canecorporation               Health        2012  not available
# 3       4         Mattouch                  NaN        2013  not available
# 4       5        Techdrill                  NaN        2009   $10,573,990
# 5       6         Techline                  NaN        2006   $13,898,119
# 6       7          Cityace          IT Services        2010    $9,254,614
# 7       8   Kayelectronics        not available        2009    $9,451,943
# 8       9          Ganzlax          IT Services        2011   $14,001,180
# 9      10      Trantraxlax  Government Services        2011   $11,088,336
#
#             Expenses      Profit   Growth
# 0                NaN   5274553.0      30%
# 1    916,455 Dollars  11412916.0      20%
# ...

# %%
 df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
 df
# Out:
#        ID             Name            COMPANIES   Inception        Revenue  \
# 0       1          Lamtone          IT Services        2009   $11,757,018
# 1       2        Stripfind   Financial Services        2010   $12,329,371
# 2       3  Canecorporation               Health        2012  not available
# 3       4         Mattouch            no values        2013  not available
# 4       5        Techdrill                  NaN        2009   $10,573,990
# 5       6         Techline                  NaN        2006   $13,898,119
# 6       7          Cityace          IT Services        2010    $9,254,614
# 7       8   Kayelectronics        not available        2009    $9,451,943
# 8       9          Ganzlax          IT Services        2011   $14,001,180
# 9      10      Trantraxlax  Government Services        2011   $11,088,336
#
#             Expenses      Profit   Growth
# 0                NaN   5274553.0      30%
# 1    916,455 Dollars  11412916.0      20%
# ...

# %%
 df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
 df
# Out:
#        ID             Name            COMPANIES   Inception        Revenue  \
# 0       1          Lamtone          IT Services        2009   $11,757,018
# 1       2        Stripfind   Financial Services        2010   $12,329,371
# 2       3  Canecorporation               Health        2012  not available
# 3       4         Mattouch                  NaN        2013  not available
# 4       5        Techdrill                  NaN        2009   $10,573,990
# 5       6         Techline                  NaN        2006   $13,898,119
# 6       7          Cityace          IT Services        2010    $9,254,614
# 7       8   Kayelectronics        not available        2009    $9,451,943
# 8       9          Ganzlax          IT Services        2011   $14,001,180
# 9      10      Trantraxlax  Government Services        2011   $11,088,336
#
#             Expenses      Profit   Growth
# 0                NaN   5274553.0      30%
# 1    916,455 Dollars  11412916.0      20%
# ...

# %%
 df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv',keep_default_na = False)
 df
# Out:
#        ID             Name            COMPANIES   Inception        Revenue  \
# 0       1          Lamtone          IT Services        2009   $11,757,018
# 1       2        Stripfind   Financial Services        2010   $12,329,371
# 2       3  Canecorporation               Health        2012  not available
# 3       4         Mattouch                 NULL        2013  not available
# 4       5        Techdrill                 #N/A        2009   $10,573,990
# 5       6         Techline                 #N/A        2006   $13,898,119
# 6       7          Cityace          IT Services        2010    $9,254,614
# 7       8   Kayelectronics        not available        2009    $9,451,943
# 8       9          Ganzlax          IT Services        2011   $14,001,180
# 9      10      Trantraxlax  Government Services        2011   $11,088,336
#
#             Expenses    Profit   Growth
# 0               null   5274553      30%
# 1    916,455 Dollars  11412916      20%
# ...

# %% [markdown]
# #### Loading the Dataset and Handling Missing Values

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv',keep_default_na = True)
df
# Out:
#        ID             Name            COMPANIES   Inception        Revenue  \
# 0       1          Lamtone          IT Services        2009   $11,757,018
# 1       2        Stripfind   Financial Services        2010   $12,329,371
# 2       3  Canecorporation               Health        2012  not available
# 3       4         Mattouch                  NaN        2013  not available
# 4       5        Techdrill                  NaN        2009   $10,573,990
# 5       6         Techline                  NaN        2006   $13,898,119
# 6       7          Cityace          IT Services        2010    $9,254,614
# 7       8   Kayelectronics        not available        2009    $9,451,943
# 8       9          Ganzlax          IT Services        2011   $14,001,180
# 9      10      Trantraxlax  Government Services        2011   $11,088,336
#
#             Expenses      Profit   Growth
# 0                NaN   5274553.0      30%
# 1    916,455 Dollars  11412916.0      20%
# ...

# %% [markdown]
# #### Loading the Dataset Without Detecting Missing Values

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', na_filter = False)
df
# Out:
#        ID             Name            COMPANIES   Inception        Revenue  \
# 0       1          Lamtone          IT Services        2009   $11,757,018
# 1       2        Stripfind   Financial Services        2010   $12,329,371
# 2       3  Canecorporation               Health        2012  not available
# 3       4         Mattouch               Health        2013  not available
# 4       5        Techdrill               Health        2009   $10,573,990
# 5       6         Techline               Health        2006   $13,898,119
# 6       7          Cityace          IT Services        2010    $9,254,614
# 7       8   Kayelectronics        not available        2009    $9,451,943
# 8       9          Ganzlax          IT Services        2011   $14,001,180
# 9      10      Trantraxlax  Government Services        2011   $11,088,336
#
#             Expenses    Profit   Growth
# 0               null   5274553      30%
# 1    916,455 Dollars  11412916      20%
# ...
