# %% [markdown]
# ## How to create CSV file #Part 2

# %%
import pandas as pd

# %%
 pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
# Out:
#      0                1                    2          3             4  \
# 0   ID             Name             Industry  Inception       Revenue
# 1    1          Lamtone          IT Services       2009  $11,757,018
# 2    2        Stripfind   Financial Services       2010  $12,329,371
# 3    3  Canecorporation               Health       2012  $10,597,009
# 4    4         Mattouch          IT Services       2013  $14,026,934
# 5    5        Techdrill               Health       2009  $10,573,990
# 6    6         Techline               Health       2006  $13,898,119
# 7    7          Cityace               Health       2010   $9,254,614
# 8    8   Kayelectronics               Health       2009   $9,451,943
# 9    9          Ganzlax          IT Services       2011  $14,001,180
# 10  10      Trantraxlax  Government Services       2011  $11,088,336
#
#                     5         6       7
# 0            Expenses    Profit  Growth
# 1   6,482,465 Dollars   5274553     30%
# ...

# %% [markdown]
# ### Header

# %%
pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv',header = 1)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
# only name the one coloumn and other coloumn make empty
pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
# Out:
#    Unnamed: 0           Dataaa           Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0          ID             Name             Industry  Inception       Revenue
# 1           1          Lamtone          IT Services       2009  $11,757,018
# 2           2        Stripfind   Financial Services       2010  $12,329,371
# 3           3  Canecorporation               Health       2012  $10,597,009
# 4           4         Mattouch          IT Services       2013  $14,026,934
# 5           5        Techdrill               Health       2009  $10,573,990
# 6           6         Techline               Health       2006  $13,898,119
# 7           7          Cityace               Health       2010   $9,254,614
# 8           8   Kayelectronics               Health       2009   $9,451,943
# 9           9          Ganzlax          IT Services       2011  $14,001,180
# 10         10      Trantraxlax  Government Services       2011  $11,088,336
#
#            Unnamed: 5 Unnamed: 6 Unnamed: 7
# ...

# %%
pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv',header = 2)
# Out:
#     1          Lamtone          IT Services  2009  $11,757,018   \
# 0   2        Stripfind   Financial Services  2010  $12,329,371
# 1   3  Canecorporation               Health  2012  $10,597,009
# 2   4         Mattouch          IT Services  2013  $14,026,934
# 3   5        Techdrill               Health  2009  $10,573,990
# 4   6         Techline               Health  2006  $13,898,119
# 5   7          Cityace               Health  2010   $9,254,614
# 6   8   Kayelectronics               Health  2009   $9,451,943
# 7   9          Ganzlax          IT Services  2011  $14,001,180
# 8  10      Trantraxlax  Government Services  2011  $11,088,336
#
#    6,482,465 Dollars   5274553  30%
# 0    916,455 Dollars  11412916  20%
# 1  7,591,189 Dollars   3005820   7%
# 2  7,429,377 Dollars   6597557  26%
# 3  7,435,363 Dollars   3138627   8%
# 4  5,470,303 Dollars   8427816  23%
# 5  6,249,498 Dollars   3005116   6%
# 6  3,878,113 Dollars   5573830   4%
# 7                NaN  11901180  18%
# ...

# %%
pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv',header = None)
# Out:
#     0                1                    2     3             4  \
# 0   1          Lamtone          IT Services  2009  $11,757,018
# 1   2        Stripfind   Financial Services  2010  $12,329,371
# 2   3  Canecorporation               Health  2012  $10,597,009
# 3   4         Mattouch          IT Services  2013  $14,026,934
# 4   5        Techdrill               Health  2009  $10,573,990
# 5   6         Techline               Health  2006  $13,898,119
# 6   7          Cityace               Health  2010   $9,254,614
# 7   8   Kayelectronics               Health  2009   $9,451,943
# 8   9          Ganzlax          IT Services  2011  $14,001,180
# 9  10      Trantraxlax  Government Services  2011  $11,088,336
#
#                    5         6    7
# 0  6,482,465 Dollars   5274553  30%
# 1    916,455 Dollars  11412916  20%
# 2  7,591,189 Dollars   3005820   7%
# 3  7,429,377 Dollars   6597557  26%
# 4  7,435,363 Dollars   3138627   8%
# 5  5,470,303 Dollars   8427816  23%
# ...

# %% [markdown]
# ### Names

# %%
pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', names = ['A','B','C','D','E','F','G','H'])
# Out:
#     A                B                    C     D             E  \
# 0   1          Lamtone          IT Services  2009  $11,757,018
# 1   2        Stripfind   Financial Services  2010  $12,329,371
# 2   3  Canecorporation               Health  2012  $10,597,009
# 3   4         Mattouch          IT Services  2013  $14,026,934
# 4   5        Techdrill               Health  2009  $10,573,990
# 5   6         Techline               Health  2006  $13,898,119
# 6   7          Cityace               Health  2010   $9,254,614
# 7   8   Kayelectronics               Health  2009   $9,451,943
# 8   9          Ganzlax          IT Services  2011  $14,001,180
# 9  10      Trantraxlax  Government Services  2011  $11,088,336
#
#                    F         G    H
# 0  6,482,465 Dollars   5274553  30%
# 1    916,455 Dollars  11412916  20%
# 2  7,591,189 Dollars   3005820   7%
# 3  7,429,377 Dollars   6597557  26%
# 4  7,435,363 Dollars   3138627   8%
# 5  5,470,303 Dollars   8427816  23%
# ...

# %%
pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', names = ['ID','NAMES','INDUSTRY','INCEPTIN','REVENUE','EXPENSES','PROFIT','GROWTH'])
# Out:
#    ID            NAMES             INDUSTRY  INCEPTIN       REVENUE  \
# 0   1          Lamtone          IT Services      2009  $11,757,018
# 1   2        Stripfind   Financial Services      2010  $12,329,371
# 2   3  Canecorporation               Health      2012  $10,597,009
# 3   4         Mattouch          IT Services      2013  $14,026,934
# 4   5        Techdrill               Health      2009  $10,573,990
# 5   6         Techline               Health      2006  $13,898,119
# 6   7          Cityace               Health      2010   $9,254,614
# 7   8   Kayelectronics               Health      2009   $9,451,943
# 8   9          Ganzlax          IT Services      2011  $14,001,180
# 9  10      Trantraxlax  Government Services      2011  $11,088,336
#
#             EXPENSES    PROFIT GROWTH
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %% [markdown]
# ### Prefix

# %%
import pandas as pd
pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv')
# Out:
#        ID             Name            COMPANIES   Inception       Revenue  \
# 0       1          Lamtone          IT Services        2009           NaN
# 1       2        Stripfind   Financial Services        2010           NaN
# 2       3  Canecorporation               Health        2012           NaN
# 3       4         Mattouch               Health        2013           NaN
# 4       5        Techdrill               Health        2009  $10,573,990
# 5       6         Techline               Health        2006  $13,898,119
# 6       7          Cityace          IT Services        2010   $9,254,614
# 7       8   Kayelectronics        not available        2009   $9,451,943
# 8       9          Ganzlax          IT Services        2011  $14,001,180
# 9      10      Trantraxlax  Government Services        2011  $11,088,336
#
#             Expenses     Profit   Growth
# 0  7,435,363 Dollars    5274553      30%
# 1    916,455 Dollars   11412916      20%
# ...

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', header=None)
df = df.add_prefix('Columns_')
df
# Out:
#    Columns_0        Columns_1            Columns_2   Columns_3     Columns_4  \
# 0         ID             Name            COMPANIES   Inception       Revenue
# 1          1          Lamtone          IT Services        2009   $11,757,018
# 2          2        Stripfind   Financial Services        2010   $12,329,371
# 3          3  Canecorporation               Health        2012   $10,597,009
# 4          4         Mattouch               Health        2013   $14,026,934
# 5          5        Techdrill               Health        2009  $13,898,119
# 6          6         Techline               Health        2006   $12,98,119
# 7          7          Cityace          IT Services        2010   $9,254,614
# 8          8   Kayelectronics        not available        2009   $9,451,943
# 9          9          Ganzlax          IT Services        2011  $14,001,180
# 10        10      Trantraxlax  Government Services        2011  $11,088,336
#
#             Columns_5  Columns_6 Columns_7
# ...

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', header=None)
df = df.add_prefix('Columns_')
print(df)
# Out:
#    Columns_0        Columns_1            Columns_2   Columns_3     Columns_4  \
# 0         ID             Name            COMPANIES   Inception       Revenue
# 1          1          Lamtone          IT Services        2009   $11,757,018
# 2          2        Stripfind   Financial Services        2010   $12,329,371
# 3          3  Canecorporation               Health        2012   $10,597,009
# 4          4         Mattouch               Health        2013   $14,026,934
# 5          5        Techdrill               Health        2009  $13,898,119
# 6          6         Techline               Health        2006   $12,98,119
# 7          7          Cityace          IT Services        2010   $9,254,614
# 8          8   Kayelectronics        not available        2009   $9,451,943
# 9          9          Ganzlax          IT Services        2011  $14,001,180
# 10        10      Trantraxlax  Government Services        2011  $11,088,336
#
#             Columns_5  Columns_6 Columns_7
# ...

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', header=None)
df = df.add_prefix('Data_')
print(df)
# Out:
#     Data_0           Data_1               Data_2      Data_3        Data_4  \
# 0       ID             Name            COMPANIES   Inception       Revenue
# 1        1          Lamtone          IT Services        2009   $11,757,018
# 2        2        Stripfind   Financial Services        2010   $12,329,371
# 3        3  Canecorporation               Health        2012   $10,597,009
# 4        4         Mattouch               Health        2013   $14,026,934
# 5        5        Techdrill               Health        2009  $13,898,119
# 6        6         Techline               Health        2006   $12,98,119
# 7        7          Cityace          IT Services        2010   $9,254,614
# 8        8   Kayelectronics        not available        2009   $9,451,943
# 9        9          Ganzlax          IT Services        2011  $14,001,180
# 10      10      Trantraxlax  Government Services        2011  $11,088,336
#
#                Data_5     Data_6    Data_7
# ...

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv', header=None)
df = df.add_prefix('Data_')
df
# Out:
#     Data_0           Data_1               Data_2      Data_3        Data_4  \
# 0       ID             Name            COMPANIES   Inception       Revenue
# 1        1          Lamtone          IT Services        2009   $11,757,018
# 2        2        Stripfind   Financial Services        2010   $12,329,371
# 3        3  Canecorporation               Health        2012   $10,597,009
# 4        4         Mattouch               Health        2013   $14,026,934
# 5        5        Techdrill               Health        2009  $13,898,119
# 6        6         Techline               Health        2006   $12,98,119
# 7        7          Cityace          IT Services        2010   $9,254,614
# 8        8   Kayelectronics        not available        2009   $9,451,943
# 9        9          Ganzlax          IT Services        2011  $14,001,180
# 10      10      Trantraxlax  Government Services        2011  $11,088,336
#
#                Data_5     Data_6    Data_7
# ...

# %% [markdown]
# ### Names Parameters

# %%
df = pd.read_csv(
    'C:\\Users\\abhishek\\Downloads\\Fortune_10.csv',
    header=None,
    names=['a','b','c','d','e','f','g','h'] )
df
# Out:
#          a                b                    c           d             e  \
# 0       ID             Name            COMPANIES   Inception       Revenue
# 1        1          Lamtone          IT Services        2009   $11,757,018
# 2        2        Stripfind   Financial Services        2010   $12,329,371
# 3        3  Canecorporation               Health        2012   $10,597,009
# 4        4         Mattouch               Health        2013   $14,026,934
# 5        5        Techdrill               Health        2009  $13,898,119
# 6        6         Techline               Health        2006   $12,98,119
# 7        7          Cityace          IT Services        2010   $9,254,614
# 8        8   Kayelectronics        not available        2009   $9,451,943
# 9        9          Ganzlax          IT Services        2011  $14,001,180
# 10      10      Trantraxlax  Government Services        2011  $11,088,336
#
#                     f          g         h
# ...

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv',header=None,names=['A','B','C','D','E','F','G','H'])
df
# Out:
#          A                B                    C           D             E  \
# 0       ID             Name            COMPANIES   Inception       Revenue
# 1        1          Lamtone          IT Services        2009   $11,757,018
# 2        2        Stripfind   Financial Services        2010   $12,329,371
# 3        3  Canecorporation               Health        2012   $10,597,009
# 4        4         Mattouch               Health        2013   $14,026,934
# 5        5        Techdrill               Health        2009  $13,898,119
# 6        6         Techline               Health        2006   $12,98,119
# 7        7          Cityace          IT Services        2010   $9,254,614
# 8        8   Kayelectronics        not available        2009   $9,451,943
# 9        9          Ganzlax          IT Services        2011  $14,001,180
# 10      10      Trantraxlax  Government Services        2011  $11,088,336
#
#                     F          G         H
# ...

# %%
df = pd.read_csv('C:\\Users\\abhishek\\Downloads\\Fortune_10.csv',header=None,names=['ID','Name','COMPANIES','Inception','Revenue','Expenses','Profit','Growth'])
df
# Out:
#         ID             Name            COMPANIES   Inception       Revenue  \
# 0       ID             Name            COMPANIES   Inception       Revenue
# 1        1          Lamtone          IT Services        2009   $11,757,018
# 2        2        Stripfind   Financial Services        2010   $12,329,371
# 3        3  Canecorporation               Health        2012   $10,597,009
# 4        4         Mattouch               Health        2013   $14,026,934
# 5        5        Techdrill               Health        2009  $13,898,119
# 6        6         Techline               Health        2006   $12,98,119
# 7        7          Cityace          IT Services        2010   $9,254,614
# 8        8   Kayelectronics        not available        2009   $9,451,943
# 9        9          Ganzlax          IT Services        2011  $14,001,180
# 10      10      Trantraxlax  Government Services        2011  $11,088,336
#
#              Expenses     Profit    Growth
# ...
